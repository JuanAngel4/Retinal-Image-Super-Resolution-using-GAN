# %% [markdown]
# # DEGRADATION METHODS

# %% [markdown]
# Thinking of accurancy, the datased selected is originated from an optical device, following this idea, the degradation metods proposed for the LR-SR model shoud be centered in optical degradation, but for researcher purposes we will be using a few more method for understaning the behavior of the model.

# %% [markdown]
# The proposed degradation models are given by:
# -
